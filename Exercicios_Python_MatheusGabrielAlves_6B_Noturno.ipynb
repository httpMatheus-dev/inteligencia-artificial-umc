# %% [markdown]
# <a href="https://colab.research.google.com/github/httpMatheus-dev/inteligencia-artificial-umc/blob/main/Exercicios_Python_MatheusGabrielAlves_6B_Noturno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios de Python — Lista 1
#
# **Aluno:** Matheus Gabriel Alves da Silva | **RGM:** 11241100109
# **Turma:** 6B — Noturno | **Disciplina:** Inteligência Artificial — UMC
